# %%
import pandas as pd
import datetime as dt

'''d = dt.datetime.today()
today = d.strftime('%m-%d-%Y')
yesterday = d - dt.timedelta(days=1)
previous = yesterday.strftime('%m-%d-%Y')'''

url = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_US.csv"
originalData = pd.read_csv(url)
'''try:
    originalData = pd.read_csv(url + today + '.csv')

except:
    today = previous
    originalData = pd.read_csv(url + today + '.csv')'''
data = originalData.copy()
data.head()
# Out:
#    UID iso2 iso3  code3  FIPS Admin2            Province_State Country_Region  \
# 0   16   AS  ASM     16  60.0    NaN            American Samoa             US
# 1  316   GU  GUM    316  66.0    NaN                      Guam             US
# 2  580   MP  MNP    580  69.0    NaN  Northern Mariana Islands             US
# 3  630   PR  PRI    630  72.0    NaN               Puerto Rico             US
# 4  850   VI  VIR    850  78.0    NaN            Virgin Islands             US
#
#        Lat     Long_  ... 4/8/20  4/9/20  4/10/20  4/11/20  4/12/20  4/13/20  \
# 0 -14.2710 -170.1320  ...      0       0        0        0        0        0
# 1  13.4443  144.7937  ...    121     128      130      133      133      133
# 2  15.0979  145.6739  ...     11      11       11       11       11       11
# 3  18.2208  -66.5901  ...    620     683      725      788      897      903
# 4  18.3358  -64.8963  ...     45      45       50       51       51       51
#
# ...

# %%
states = data.sort_values(by = 'Province_State').rename(columns={'Admin2':'County', 'Province_State':'State'})
states.set_index('County', inplace=True)
#ny[(ny['State'] == "New York")][['Confirmed', 'Deaths', 'Active']].sort_values(by='Confirmed', ascending=False).head(10)
states
# Out:
#                   UID iso2 iso3  code3     FIPS      State Country_Region  \
# County
# Madison      84001089   US  USA    840   1089.0    Alabama             US
# Mobile       84001097   US  USA    840   1097.0    Alabama             US
# Marshall     84001095   US  USA    840   1095.0    Alabama             US
# Marion       84001093   US  USA    840   1093.0    Alabama             US
# Marengo      84001091   US  USA    840   1091.0    Alabama             US
# Macon        84001087   US  USA    840   1087.0    Alabama             US
# Lowndes      84001085   US  USA    840   1085.0    Alabama             US
# Monroe       84001099   US  USA    840   1099.0    Alabama             US
# Limestone    84001083   US  USA    840   1083.0    Alabama             US
# Lawrence     84001079   US  USA    840   1079.0    Alabama             US
# Lauderdale   84001077   US  USA    840   1077.0    Alabama             US
# Lamar        84001075   US  USA    840   1075.0    Alabama             US
# ...
